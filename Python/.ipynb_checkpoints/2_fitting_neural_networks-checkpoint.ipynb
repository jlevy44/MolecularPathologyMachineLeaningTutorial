# %% [markdown]
# ## Package Imports

# %%
import pandas as pd, numpy as np
import seaborn as sns, matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, classification_report
from mlxtend.evaluate import bootstrap
from numpy import format_float_scientific
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
import tensorflow as tf
from keras.optimizers.adam import Adam
import keras
from keras import metrics
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import Model
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
import warnings
warnings.filterwarnings("ignore")
import matplotlib
matplotlib.rcParams['figure.dpi']=300
# note: need mkl and libcblas installed
# ! conda install -y -c conda-forge mkl openblas
# for apple M1/M2, install tensorflow/keras ! pip install tensorflow-macos tensorflow-metal

# %% [markdown]
# ## Misc. Functions

# %%
def extract_ys(Y):
    return Y[:,0], Y[:,1]

def auc(Y):
    y_true, y_pred=extract_ys(Y)
    return roc_auc_score(y_true, y_pred)

def return_bootstrap_results(results,fn,round_place=1):
    Y=results[['y_true','y_pred_probs']].values
    original, std_err, ci_bounds = bootstrap(Y, num_rounds=1000,
                                             func=fn,
                                             ci=0.95,
                                             seed=123)
    std_err=format_float_scientific(std_err,round_place)
    if float(std_err) >= 0.001:
        std_err=float(std_err)
    
    return "{}±{}".format(float(format_float_scientific(original,round_place)),2*std_err)

# %% [markdown]
# ## Import Data

# %%
data=pd.read_csv("../data/leukemia.csv",header=None)

# %% [markdown]
# ## Generate outcome variable and randomly subselect columns to save compute time since this is a toy example

# %%
np.random.seed(42)
Y=data.iloc[:,0].map(lambda x: x.endswith("ALL")).astype(int)
X=data.iloc[:,:-1]
X=X.sample(axis='columns',n=30)

# %% [markdown]
# ## Generate Train Test Splits

# %%
np.random.seed(42)
X_train,X_test,y_train,y_test = train_test_split(X,Y,train_size=0.7,stratify=Y,random_state=42)

# %% [markdown]
# ## Train classification neural network
# - 3-fold cross validation within training set (successive partitions of training set to select ideal hyperparameters)

# %%
def generate_model():
    model = Sequential()
    model.add(Dense(12, input_dim=30, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=1e-2, weight_decay=1e-6), metrics=["accuracy"])
    return model

np.random.seed(42)
estimator=KerasClassifier
param_grid = dict(batch_size=[10, 20], epochs=[10, 50])
grid_search = GridSearchCV(estimator=estimator(build_fn=generate_model,verbose=0), param_grid=param_grid, scoring='roc_auc', cv=5, verbose=False)
grid_search.fit(X_train,y_train)
best_params=grid_search.best_params_

options=best_params
options.update(dict(build_fn=generate_model,verbose=0))
best_estimator=estimator(**options)
best_estimator.fit(X_train,y_train)
y_pred=best_estimator.predict(X_test)
y_pred_probs=best_estimator.predict_proba(X_test)[:,1]
# Out:
# 2024-02-26 09:57:53.275281: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:57:54.554101: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:57:55.856963: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:57:57.145150: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:57:58.519324: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:57:59.908965: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:03.696878: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:07.434262: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:11.383252: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:15.296313: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:19.309688: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:20.523184: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:21.744592: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:23.040235: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:24.354668: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:25.692466: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:28.653502: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:31.219413: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:33.851332: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:36.504603: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:39.221055: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-26 09:58:41.019272: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 17ms/step
# 2024-02-26 09:58:42.679916: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# ## Classification performance on test set

# %%
print(classification_report(y_test,y_pred))
df_confusion=pd.DataFrame(confusion_matrix(y_test,y_pred))
df_confusion.index=pd.MultiIndex.from_frame(pd.DataFrame([("Prediction",x) for x in [0,1]]))
df_confusion.columns=pd.MultiIndex.from_frame(pd.DataFrame([("Reference",x) for x in [0,1]]))
df_confusion
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         8
#            1       0.86      0.86      0.86        14
#
#     accuracy                           0.82        22
#    macro avg       0.80      0.80      0.80        22
# weighted avg       0.82      0.82      0.82        22
# 0            Reference
# 1                    0   1
# 0          1
# Prediction 0         6   2
#            1         2  12

# %% [markdown]
# ## Receiver operating characteristic curve and concordance on test set

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs, drop_intermediate=False)
roc_df = pd.DataFrame(np.vstack([fpr,tpr,thresholds]).T,columns=['1-Specificity','Sensitivity','Thresholds'])
results=pd.DataFrame(np.vstack([y_test.values,y_pred.flatten(),y_pred_probs]).T,columns=['y_true','y_pred','y_pred_probs'])

plt.figure()
ax=sns.lineplot(x='1-Specificity',y='Sensitivity',data=roc_df)
plt.title("AUC: {}".format(return_bootstrap_results(results,auc,2)))
plt.xlabel('1-Specificity')
plt.ylabel('Sensitivity')
sns.despine()

# %% [markdown]
# # Unsupervised Learning
# # Generate autoencoder for unsupervised dimensionality reduction
# - autoencoder is comprised of:
#   - an encoder, which projects the data, X -> Z
#   - a decoder, which reconstructs the original data, Z -> X
#
# # Generate network, Fit and Plot

# %%
def generate_model():
    model = Sequential()
    # encoder layers
    model.add(Dense(12, input_dim=30, activation='relu'))
    model.add(Dropout(rate=0.1))
    model.add(Dense(2, activation='relu',name="hidden"))
    model.add(Dropout(rate=0.1))
    # decoder layers
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(rate=0.1))
    model.add(Dense(30))
    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=1e-2, weight_decay=1e-4), metrics=["mean_squared_error"])
    return model

np.random.seed(42)
estimator=KerasRegressor(build_fn=generate_model,verbose=1,batch_size=64,epochs=100)
estimator.fit(X,X)
estimator.model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=1e-2, weight_decay=1e-4), metrics=["mean_squared_error"])
# Out:
# Epoch 1/100
# 2024-02-26 10:03:55.167072: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2/2 [==============================] - 2s 263ms/step - loss: 1.4941 - mean_squared_error: 1.4941
# Epoch 2/100
# 2/2 [==============================] - 0s 87ms/step - loss: 1.2539 - mean_squared_error: 1.2539
# Epoch 3/100
# 2/2 [==============================] - 0s 120ms/step - loss: 1.1062 - mean_squared_error: 1.1062
# Epoch 4/100
# 2/2 [==============================] - 0s 94ms/step - loss: 1.0068 - mean_squared_error: 1.0068
# Epoch 5/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.9953 - mean_squared_error: 0.9953
# Epoch 6/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.9619 - mean_squared_error: 0.9619
# Epoch 7/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.9498 - mean_squared_error: 0.9498
# Epoch 8/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9405 - mean_squared_error: 0.9405
# Epoch 9/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.9317 - mean_squared_error: 0.9317
# Epoch 10/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.9312 - mean_squared_error: 0.9312
# Epoch 11/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.9315 - mean_squared_error: 0.9315
# Epoch 12/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.9101 - mean_squared_error: 0.9101
# Epoch 13/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.9047 - mean_squared_error: 0.9047
# Epoch 14/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8936 - mean_squared_error: 0.8936
# Epoch 15/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8994 - mean_squared_error: 0.8994
# Epoch 16/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8885 - mean_squared_error: 0.8885
# Epoch 17/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8744 - mean_squared_error: 0.8744
# Epoch 18/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.8725 - mean_squared_error: 0.8725
# Epoch 19/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8847 - mean_squared_error: 0.8847
# Epoch 20/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8635 - mean_squared_error: 0.8635
# Epoch 21/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.8632 - mean_squared_error: 0.8632
# Epoch 22/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8636 - mean_squared_error: 0.8636
# Epoch 23/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.8702 - mean_squared_error: 0.8702
# Epoch 24/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8601 - mean_squared_error: 0.8601
# Epoch 25/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8457 - mean_squared_error: 0.8457
# Epoch 26/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.8426 - mean_squared_error: 0.8426
# Epoch 27/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.8625 - mean_squared_error: 0.8625
# Epoch 28/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8508 - mean_squared_error: 0.8508
# Epoch 29/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.8491 - mean_squared_error: 0.8491
# Epoch 30/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8442 - mean_squared_error: 0.8442
# Epoch 31/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.8422 - mean_squared_error: 0.8422
# Epoch 32/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8343 - mean_squared_error: 0.8343
# Epoch 33/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8391 - mean_squared_error: 0.8391
# Epoch 34/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.8323 - mean_squared_error: 0.8323
# Epoch 35/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8241 - mean_squared_error: 0.8241
# Epoch 36/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8531 - mean_squared_error: 0.8531
# Epoch 37/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8406 - mean_squared_error: 0.8406
# Epoch 38/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8305 - mean_squared_error: 0.8305
# Epoch 39/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8327 - mean_squared_error: 0.8327
# Epoch 40/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8270 - mean_squared_error: 0.8270
# Epoch 41/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8385 - mean_squared_error: 0.8385
# Epoch 42/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8386 - mean_squared_error: 0.8386
# Epoch 43/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8346 - mean_squared_error: 0.8346
# Epoch 44/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8382 - mean_squared_error: 0.8382
# Epoch 45/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8421 - mean_squared_error: 0.8421
# Epoch 46/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8437 - mean_squared_error: 0.8437
# Epoch 47/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8386 - mean_squared_error: 0.8386
# Epoch 48/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8307 - mean_squared_error: 0.8307
# Epoch 49/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8321 - mean_squared_error: 0.8321
# Epoch 50/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8609 - mean_squared_error: 0.8609
# Epoch 51/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8330 - mean_squared_error: 0.8330
# Epoch 52/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8388 - mean_squared_error: 0.8388
# Epoch 53/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8284 - mean_squared_error: 0.8284
# Epoch 54/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8438 - mean_squared_error: 0.8438
# Epoch 55/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.8291 - mean_squared_error: 0.8291
# Epoch 56/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8369 - mean_squared_error: 0.8369
# Epoch 57/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8232 - mean_squared_error: 0.8232
# Epoch 58/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8399 - mean_squared_error: 0.8399
# Epoch 59/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8150 - mean_squared_error: 0.8150
# Epoch 60/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8663 - mean_squared_error: 0.8663
# Epoch 61/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8288 - mean_squared_error: 0.8288
# Epoch 62/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8515 - mean_squared_error: 0.8515
# Epoch 63/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8430 - mean_squared_error: 0.8430
# Epoch 64/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8289 - mean_squared_error: 0.8289
# Epoch 65/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8113 - mean_squared_error: 0.8113
# Epoch 66/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8208 - mean_squared_error: 0.8208
# Epoch 67/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8254 - mean_squared_error: 0.8254
# Epoch 68/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8082 - mean_squared_error: 0.8082
# Epoch 69/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8225 - mean_squared_error: 0.8225
# Epoch 70/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8309 - mean_squared_error: 0.8309
# Epoch 71/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8117 - mean_squared_error: 0.8117
# Epoch 72/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8314 - mean_squared_error: 0.8314
# Epoch 73/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8175 - mean_squared_error: 0.8175
# Epoch 74/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8301 - mean_squared_error: 0.8301
# Epoch 75/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8108 - mean_squared_error: 0.8108
# Epoch 76/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8282 - mean_squared_error: 0.8282
# Epoch 77/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.8127 - mean_squared_error: 0.8127
# Epoch 78/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8158 - mean_squared_error: 0.8158
# Epoch 79/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8307 - mean_squared_error: 0.8307
# Epoch 80/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8256 - mean_squared_error: 0.8256
# Epoch 81/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8239 - mean_squared_error: 0.8239
# Epoch 82/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8369 - mean_squared_error: 0.8369
# Epoch 83/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8308 - mean_squared_error: 0.8308
# Epoch 84/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8198 - mean_squared_error: 0.8198
# Epoch 85/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8326 - mean_squared_error: 0.8326
# Epoch 86/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8196 - mean_squared_error: 0.8196
# Epoch 87/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8260 - mean_squared_error: 0.8260
# Epoch 88/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8141 - mean_squared_error: 0.8141
# Epoch 89/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8390 - mean_squared_error: 0.8390
# Epoch 90/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8122 - mean_squared_error: 0.8122
# Epoch 91/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8421 - mean_squared_error: 0.8421
# Epoch 92/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8116 - mean_squared_error: 0.8116
# Epoch 93/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.8261 - mean_squared_error: 0.8261
# Epoch 94/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8248 - mean_squared_error: 0.8248
# Epoch 95/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8289 - mean_squared_error: 0.8289
# Epoch 96/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8258 - mean_squared_error: 0.8258
# Epoch 97/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8177 - mean_squared_error: 0.8177
# Epoch 98/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8430 - mean_squared_error: 0.8430
# Epoch 99/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8161 - mean_squared_error: 0.8161
# Epoch 100/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8162 - mean_squared_error: 0.8162

# %%
estimator.model = Model(inputs=estimator.model.input, outputs=estimator.model.get_layer('hidden').output)

# %%
t_data=pd.DataFrame(estimator.predict(X),columns=['x','y'])
t_data['ALL']=Y
sns.scatterplot(x='x',y='y',hue="ALL",data=t_data)
sns.despine()
# Out:
# 2/2 [==============================] - 0s 7ms/step
# 2024-02-26 10:04:05.625774: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# ## PCA

# %%
np.random.seed(42)
t_data=pd.DataFrame(PCA(n_components=2,random_state=42).fit_transform(X),columns=['x','y'])
t_data['ALL']=Y
sns.scatterplot(x='x',y='y',hue="ALL",data=t_data)
sns.despine()
